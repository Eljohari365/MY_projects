# %% [markdown]
# # Homework and bakeoff: Few-shot OpenQA with DSPy

# %%
__author__ = "Christopher Potts and Omar Khattab"
__version__ = "CS224u, Stanford, Fall 2024"

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cgpotts/cs224u/blob/master/hw_openqa.ipynb)
#
# If Colab is opened with this badge, please **save a copy to drive** (from the File menu) before running the notebook.

# %% [markdown]
# ## Overview

# %% [markdown]
# The goal of this homework is to explore retrieval-augmented in-context learning. This is an exciting area that brings together a number of recent task ideas and modeling innovations. We will use the [DSPy programming library](http://dspy.ai) to build systems in this new mode.
#
# Our core task is __open-domain question answering (OpenQA)__. In this task, all that is given by the dataset is a question text, and the task is to answer that question. By contrast, in many modern QA tasks, the dataset provides a text and a gold passage, usually with a firm guarantee that the answer will be a substring of the passage.
#
# OpenQA is substantially harder than standard QA. The usual strategy is to use a _retriever_ to find passages in a large collection of texts and train a _reader_ to find answers in those passages. This means we have no guarantee that the retrieved passage will contain the answer we need. If we don't retrieve a passage containing the answer, our reader has no hope of succeeding. Although this is challenging, it is much more realistic and widely applicable than standard QA. After all, with the right retriever, an OpenQA system could be deployed over the entire Web.
#
# The task posed by this homework is harder even than OpenQA. We are calling this task __few-shot OpenQA__. The defining feature of this task is that the reader is simply a frozen, general purpose language model. It accepts string inputs (prompts) and produces text in response. It is not trained to answer questions per se, and nothing about its structure ensures that it will respond with a substring of the prompt corresponding to anything like an answer.
#
# __Few-shot QA__ (but not OpenQA!) is explored in the famous GPT-3 paper ([Brown et al. 2020](https://arxiv.org/abs/2005.14165)). The authors are able to get traction on the problem using GPT-3, an incredible finding. Our task here – __few-shot OpenQA__ – pushes this even further by retrieving passages to use in the prompt rather than assuming that the gold passage can be used in the prompt. If we can make this work, then it should be a major step towards flexibly and easily deploying QA technologies in new domains.
#
# In summary:
#
# | Task             | Passage given | Task-specific reader training |Task-specific retriever training  |
# |-----------------:|:-------------:|:-----------------------------:|:--------------------------------:|
# | QA               | yes           | yes                           | n/a                              |
# | OpenQA           | no            | yes                           | maybe                            |
# | Few-shot QA      | yes           | no                            | n/a                              |
# | Few-shot OpenQA  | no            | no                            | maybe                            |
#
# Just to repeat: your mission is to explore the final line in this table. The core notebook and assignment don't address the issue of training the retriever in a task-specific way, but this is something you could pursue for a final project; [the ColBERT codebase](https://github.com/stanford-futuredata/ColBERT) makes easy.
#
# It is a requirement of the bake-off that a general-purpose language model be used. In particular, trained QA systems cannot be used at all, and no fine-tuning is allowed either. See the original system question at the bottom of this message for guidance on which models are allowed.
#
# Note: the models we are working with here are _big_. This poses a challenge that is increasingly common in NLP: you have to pay one way or another. You can pay to use the GPT-3 API, or you can pay to use a local model on a heavy-duty cluster computer, or you can pay with time by using a local model on a more modest computer.

# %% [markdown]
# ## Set-up

# %% [markdown]
# We have sought to make this notebook self-contained and easy to use on a personal computer, on Google Colab, and in Sagemaker Studio. For personal computer use, we assume you have already done everything in [setup.ipynb](setup.ipynb]). For cloud usage, the next few code blocks should handle all set-up steps.

# %%
try:
    import datasets
    root_path = '.'
except ModuleNotFoundError:
    # !git clone https://github.com/cgpotts/cs224u/
    # !pip install -r cs224u/requirements.txt
    root_path = 'dspy'
# Out:
# Cloning into 'cs224u'...
# Requirement already satisfied: numpy>=1.20.0 in c:\users\user\anaconda3\lib\site-packages (from -r cs224u/requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\user\anaconda3\lib\site-packages (from -r cs224u/requirements.txt (line 2)) (1.13.1)
# Requirement already satisfied: matplotlib>=3.7.0 in c:\users\user\anaconda3\lib\site-packages (from -r cs224u/requirements.txt (line 3)) (3.9.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\user\anaconda3\lib\site-packages (from -r cs224u/requirements.txt (line 4)) (1.5.1)
# Requirement already satisfied: nltk>=3.7 in c:\users\user\anaconda3\lib\site-packages (from -r cs224u/requirements.txt (line 5)) (3.9.1)
# Requirement already satisfied: pytest>=7.1 in c:\users\user\anaconda3\lib\site-packages (from -r cs224u/requirements.txt (line 6)) (7.4.4)
# Requirement already satisfied: jupyter>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from -r cs224u/requirements.txt (line 7)) (1.0.0)
# Requirement already satisfied: pandas>=1.5 in c:\users\user\anaconda3\lib\site-packages (from -r cs224u/requirements.txt (line 8)) (2.2.3)
# Collecting transformers>=4.37 (from -r cs224u/requirements.txt (line 16))
#   Downloading transformers-5.5.0-py3-none-any.whl.metadata (32 kB)
# Collecting datasets>=2.14.6 (from -r cs224u/requirements.txt (line 17))
#   Downloading datasets-4.8.4-py3-none-any.whl.metadata (19 kB)
# Collecting spacy>=3.7.2 (from -r cs224u/requirements.txt (line 18))
#   Downloading spacy-3.8.14-cp312-cp312-win_amd64.whl.metadata (28 kB)
# Collecting colbert-ai>=0.2.20 (from -r cs224u/requirements.txt (line 19))
#   Downloading colbert_ai-0.2.22-py3-none-any.whl.metadata (12 kB)
# Collecting dspy-ai==2.4.13 (from -r cs224u/requirements.txt (line 21))
#   Downloading dspy_ai-2.4.13-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: python-dotenv in c:\users\user\anaconda3\lib\site-packages (from -r cs224u/requirements.txt (line 22)) (0.21.0)
# Collecting wget (from -r cs224u/requirements.txt (line 23))
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting openai==1.61.1 (from -r cs224u/requirements.txt (line 24))
#   Downloading openai-1.61.1-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: backoff in c:\users\user\anaconda3\lib\site-packages (from dspy-ai==2.4.13->-r cs224u/requirements.txt (line 21)) (2.2.1)
# Requirement already satisfied: joblib~=1.3 in c:\users\user\anaconda3\lib\site-packages (from dspy-ai==2.4.13->-r cs224u/requirements.txt (line 21)) (1.4.2)
# Collecting optuna (from dspy-ai==2.4.13->-r cs224u/requirements.txt (line 21))
#   Downloading optuna-4.8.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pydantic~=2.0 in c:\users\user\anaconda3\lib\site-packages (from dspy-ai==2.4.13->-r cs224u/requirements.txt (line 21)) (2.8.2)
# Requirement already satisfied: regex in c:\users\user\anaconda3\lib\site-packages (from dspy-ai==2.4.13->-r cs224u/requirements.txt (line 21)) (2024.9.11)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from dspy-ai==2.4.13->-r cs224u/requirements.txt (line 21)) (2.32.5)
# Collecting structlog (from dspy-ai==2.4.13->-r cs224u/requirements.txt (line 21))
#   Downloading structlog-25.5.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from dspy-ai==2.4.13->-r cs224u/requirements.txt (line 21)) (4.66.5)
# Requirement already satisfied: ujson in c:\users\user\anaconda3\lib\site-packages (from dspy-ai==2.4.13->-r cs224u/requirements.txt (line 21)) (5.10.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\user\anaconda3\lib\site-packages (from openai==1.61.1->-r cs224u/requirements.txt (line 24)) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\user\anaconda3\lib\site-packages (from openai==1.61.1->-r cs224u/requirements.txt (line 24)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\anaconda3\lib\site-packages (from openai==1.61.1->-r cs224u/requirements.txt (line 24)) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\user\anaconda3\lib\site-packages (from openai==1.61.1->-r cs224u/requirements.txt (line 24)) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from openai==1.61.1->-r cs224u/requirements.txt (line 24)) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\user\anaconda3\lib\site-packages (from openai==1.61.1->-r cs224u/requirements.txt (line 24)) (4.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.7.0->-r cs224u/requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.7.0->-r cs224u/requirements.txt (line 3)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.7.0->-r cs224u/requirements.txt (line 3)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.7.0->-r cs224u/requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.7.0->-r cs224u/requirements.txt (line 3)) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.7.0->-r cs224u/requirements.txt (line 3)) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.7.0->-r cs224u/requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.7.0->-r cs224u/requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->-r cs224u/requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: click in c:\users\user\anaconda3\lib\site-packages (from nltk>=3.7->-r cs224u/requirements.txt (line 5)) (8.1.7)
# Requirement already satisfied: iniconfig in c:\users\user\anaconda3\lib\site-packages (from pytest>=7.1->-r cs224u/requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\user\anaconda3\lib\site-packages (from pytest>=7.1->-r cs224u/requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from pytest>=7.1->-r cs224u/requirements.txt (line 6)) (0.4.6)
# Requirement already satisfied: notebook in c:\users\user\anaconda3\lib\site-packages (from jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (7.2.2)
# Requirement already satisfied: qtconsole in c:\users\user\anaconda3\lib\site-packages (from jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (5.5.1)
# Requirement already satisfied: jupyter-console in c:\users\user\anaconda3\lib\site-packages (from jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\user\anaconda3\lib\site-packages (from jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (7.16.4)
# Requirement already satisfied: ipykernel in c:\users\user\anaconda3\lib\site-packages (from jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (6.28.0)
# Requirement already satisfied: ipywidgets in c:\users\user\anaconda3\lib\site-packages (from jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (7.8.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.5->-r cs224u/requirements.txt (line 8)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.5->-r cs224u/requirements.txt (line 8)) (2023.3)
# Collecting huggingface-hub<2.0,>=1.5.0 (from transformers>=4.37->-r cs224u/requirements.txt (line 16))
#   Downloading huggingface_hub-1.9.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\user\anaconda3\lib\site-packages (from transformers>=4.37->-r cs224u/requirements.txt (line 16)) (6.0.1)
# Collecting regex (from dspy-ai==2.4.13->-r cs224u/requirements.txt (line 21))
#   Downloading regex-2026.4.4-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\user\anaconda3\lib\site-packages (from transformers>=4.37->-r cs224u/requirements.txt (line 16)) (0.22.2)
# Requirement already satisfied: typer in c:\users\user\anaconda3\lib\site-packages (from transformers>=4.37->-r cs224u/requirements.txt (line 16)) (0.21.1)
# Collecting safetensors>=0.4.3 (from transformers>=4.37->-r cs224u/requirements.txt (line 16))
#   Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from datasets>=2.14.6->-r cs224u/requirements.txt (line 17)) (3.13.1)
# Collecting pyarrow>=21.0.0 (from datasets>=2.14.6->-r cs224u/requirements.txt (line 17))
#   Downloading pyarrow-23.0.1-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from datasets>=2.14.6->-r cs224u/requirements.txt (line 17)) (0.3.8)
# Requirement already satisfied: xxhash in c:\users\user\anaconda3\lib\site-packages (from datasets>=2.14.6->-r cs224u/requirements.txt (line 17)) (3.6.0)
# Collecting multiprocess<0.70.20 (from datasets>=2.14.6->-r cs224u/requirements.txt (line 17))
#   Downloading multiprocess-0.70.19-py312-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in c:\users\user\anaconda3\lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.14.6->-r cs224u/requirements.txt (line 17)) (2024.6.1)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy>=3.7.2->-r cs224u/requirements.txt (line 18))
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy>=3.7.2->-r cs224u/requirements.txt (line 18))
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy>=3.7.2->-r cs224u/requirements.txt (line 18))
#   Downloading murmurhash-1.0.15-cp312-cp312-win_amd64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy>=3.7.2->-r cs224u/requirements.txt (line 18))
#   Downloading cymem-2.0.13-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy>=3.7.2->-r cs224u/requirements.txt (line 18))
#   Downloading preshed-3.0.13-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting thinc<8.4.0,>=8.3.12 (from spacy>=3.7.2->-r cs224u/requirements.txt (line 18))
#   Downloading thinc-8.3.13-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy>=3.7.2->-r cs224u/requirements.txt (line 18))
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.5.3 (from spacy>=3.7.2->-r cs224u/requirements.txt (line 18))
#   Downloading srsly-2.5.3-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy>=3.7.2->-r cs224u/requirements.txt (line 18))
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<2.0.0,>=1.0.0 (from spacy>=3.7.2->-r cs224u/requirements.txt (line 18))
#   Downloading weasel-1.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting confection<2.0.0,>=1.3.2 (from spacy>=3.7.2->-r cs224u/requirements.txt (line 18))
#   Downloading confection-1.3.3-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from spacy>=3.7.2->-r cs224u/requirements.txt (line 18)) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from spacy>=3.7.2->-r cs224u/requirements.txt (line 18)) (75.1.0)
# Collecting bitarray (from colbert-ai>=0.2.20->-r cs224u/requirements.txt (line 19))
#   Downloading bitarray-3.8.1-cp312-cp312-win_amd64.whl.metadata (35 kB)
# Requirement already satisfied: flask in c:\users\user\anaconda3\lib\site-packages (from colbert-ai>=0.2.20->-r cs224u/requirements.txt (line 19)) (3.0.3)
# Requirement already satisfied: GitPython in c:\users\user\anaconda3\lib\site-packages (from colbert-ai>=0.2.20->-r cs224u/requirements.txt (line 19)) (3.1.43)
# Collecting ninja (from colbert-ai>=0.2.20->-r cs224u/requirements.txt (line 19))
#   Downloading ninja-1.13.0-py3-none-win_amd64.whl.metadata (5.1 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\user\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai==1.61.1->-r cs224u/requirements.txt (line 24)) (3.7)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\user\anaconda3\lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.14.6->-r cs224u/requirements.txt (line 17)) (3.10.5)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai==1.61.1->-r cs224u/requirements.txt (line 24)) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai==1.61.1->-r cs224u/requirements.txt (line 24)) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.61.1->-r cs224u/requirements.txt (line 24)) (0.14.0)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub<2.0,>=1.5.0->transformers>=4.37->-r cs224u/requirements.txt (line 16))
#   Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Collecting dill<0.4.2,>=0.3.0 (from datasets>=2.14.6->-r cs224u/requirements.txt (line 17))
#   Downloading dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic~=2.0->dspy-ai==2.4.13->-r cs224u/requirements.txt (line 21)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\user\anaconda3\lib\site-packages (from pydantic~=2.0->dspy-ai==2.4.13->-r cs224u/requirements.txt (line 21)) (2.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->-r cs224u/requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests->dspy-ai==2.4.13->-r cs224u/requirements.txt (line 21)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->dspy-ai==2.4.13->-r cs224u/requirements.txt (line 21)) (2.2.3)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.12->spacy>=3.7.2->-r cs224u/requirements.txt (line 18))
#   Downloading blis-1.3.3-cp312-cp312-win_amd64.whl.metadata (7.7 kB)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\user\anaconda3\lib\site-packages (from typer->transformers>=4.37->-r cs224u/requirements.txt (line 16)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\user\anaconda3\lib\site-packages (from typer->transformers>=4.37->-r cs224u/requirements.txt (line 16)) (13.7.1)
# Collecting cloudpathlib>=0.7.0 (from weasel<2.0.0,>=1.0.0->spacy>=3.7.2->-r cs224u/requirements.txt (line 18))
#   Downloading cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: smart-open>=5.2.1 in c:\users\user\anaconda3\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy>=3.7.2->-r cs224u/requirements.txt (line 18)) (5.2.1)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\user\anaconda3\lib\site-packages (from flask->colbert-ai>=0.2.20->-r cs224u/requirements.txt (line 19)) (3.0.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\user\anaconda3\lib\site-packages (from flask->colbert-ai>=0.2.20->-r cs224u/requirements.txt (line 19)) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\user\anaconda3\lib\site-packages (from flask->colbert-ai>=0.2.20->-r cs224u/requirements.txt (line 19)) (1.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->spacy>=3.7.2->-r cs224u/requirements.txt (line 18)) (2.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\user\anaconda3\lib\site-packages (from GitPython->colbert-ai>=0.2.20->-r cs224u/requirements.txt (line 19)) (4.0.7)
# Requirement already satisfied: comm>=0.1.1 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (8.27.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (1.6.0)
# Requirement already satisfied: psutil in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (5.14.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (1.0.0)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\user\anaconda3\lib\site-packages (from jupyter-console->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (3.0.43)
# Requirement already satisfied: pygments in c:\users\user\anaconda3\lib\site-packages (from jupyter-console->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (2.15.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (1.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.2.3)
# Collecting alembic>=1.5.0 (from optuna->dspy-ai==2.4.13->-r cs224u/requirements.txt (line 21))
#   Downloading alembic-1.18.4-py3-none-any.whl.metadata (7.2 kB)
# Collecting colorlog (from optuna->dspy-ai==2.4.13->-r cs224u/requirements.txt (line 21))
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\user\anaconda3\lib\site-packages (from optuna->dspy-ai==2.4.13->-r cs224u/requirements.txt (line 21)) (2.0.34)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from qtconsole->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (2.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.14.6->-r cs224u/requirements.txt (line 17)) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\user\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.14.6->-r cs224u/requirements.txt (line 17)) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.14.6->-r cs224u/requirements.txt (line 17)) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.14.6->-r cs224u/requirements.txt (line 17)) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.14.6->-r cs224u/requirements.txt (line 17)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets>=2.14.6->-r cs224u/requirements.txt (line 17)) (1.11.0)
# Collecting Mako (from alembic>=1.5.0->optuna->dspy-ai==2.4.13->-r cs224u/requirements.txt (line 21))
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: webencodings in c:\users\user\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.5.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\user\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->GitPython->colbert-ai>=0.2.20->-r cs224u/requirements.txt (line 19)) (4.0.0)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.19.1)
# Requirement already satisfied: stack-data in c:\users\user\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\user\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\user\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (305.1)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (4.23.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\user\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.2.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\user\anaconda3\lib\site-packages (from rich>=10.11.0->typer->transformers>=4.37->-r cs224u/requirements.txt (line 16)) (2.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\lib\site-packages (from sqlalchemy>=1.4.2->optuna->dspy-ai==2.4.13->-r cs224u/requirements.txt (line 21)) (3.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (2.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\user\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\user\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.8.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\user\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (2.0.7)
# Requirement already satisfied: rfc3339-validator in c:\users\user\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\user\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.1.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->transformers>=4.37->-r cs224u/requirements.txt (line 16)) (0.1.0)
# Requirement already satisfied: executing in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (0.2.2)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7))
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7))
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\user\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7))
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7))
#   Downloading webcolors-25.10.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\user\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter>=1.0.0->-r cs224u/requirements.txt (line 7)) (1.2.3)
# Downloading dspy_ai-2.4.13-py3-none-any.whl (280 kB)
# Downloading openai-1.61.1-py3-none-any.whl (463 kB)
# Downloading transformers-5.5.0-py3-none-any.whl (10.2 MB)
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/10.2 MB 4.2 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/10.2 MB 3.8 MB/s eta 0:00:03
#    --------- ------------------------------ 2.4/10.2 MB 3.8 MB/s eta 0:00:03
#    ------------ --------------------------- 3.1/10.2 MB 3.8 MB/s eta 0:00:02
#    --------------- ------------------------ 3.9/10.2 MB 3.9 MB/s eta 0:00:02
#    ------------------ --------------------- 4.7/10.2 MB 3.9 MB/s eta 0:00:02
#    --------------------- ------------------ 5.5/10.2 MB 3.8 MB/s eta 0:00:02
#    ------------------------ --------------- 6.3/10.2 MB 3.9 MB/s eta 0:00:02
#    --------------------------- ------------ 7.1/10.2 MB 3.8 MB/s eta 0:00:01
#    ------------------------------ --------- 7.9/10.2 MB 3.8 MB/s eta 0:00:01
#    --------------------------------- ------ 8.7/10.2 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------ --- 9.4/10.2 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.2/10.2 MB 3.8 MB/s eta 0:00:00
# Downloading datasets-4.8.4-py3-none-any.whl (526 kB)
#    ---------------------------------------- 0.0/527.0 kB ? eta -:--:--
#    ---------------------------------------- 527.0/527.0 kB 3.4 MB/s eta 0:00:00
# Downloading spacy-3.8.14-cp312-cp312-win_amd64.whl (14.2 MB)
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/14.2 MB 3.3 MB/s eta 0:00:05
#    --- ------------------------------------ 1.3/14.2 MB 3.5 MB/s eta 0:00:04
#    ----- ---------------------------------- 2.1/14.2 MB 3.6 MB/s eta 0:00:04
#    -------- ------------------------------- 2.9/14.2 MB 3.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.7/14.2 MB 3.6 MB/s eta 0:00:03
#    ------------ --------------------------- 4.5/14.2 MB 3.6 MB/s eta 0:00:03
#    -------------- ------------------------- 5.2/14.2 MB 3.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 6.0/14.2 MB 3.6 MB/s eta 0:00:03
#    ------------------ --------------------- 6.6/14.2 MB 3.6 MB/s eta 0:00:03
#    -------------------- ------------------- 7.3/14.2 MB 3.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 8.1/14.2 MB 3.6 MB/s eta 0:00:02
#    ------------------------- -------------- 8.9/14.2 MB 3.6 MB/s eta 0:00:02
#    --------------------------- ------------ 9.7/14.2 MB 3.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 10.2/14.2 MB 3.6 MB/s eta 0:00:02
#    ------------------------------ --------- 11.0/14.2 MB 3.6 MB/s eta 0:00:01
#    --------------------------------- ------ 11.8/14.2 MB 3.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.6/14.2 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 13.4/14.2 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  14.2/14.2 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 14.2/14.2 MB 3.6 MB/s eta 0:00:00
# Downloading colbert_ai-0.2.22-py3-none-any.whl (116 kB)
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading confection-1.3.3-py3-none-any.whl (35 kB)
# Downloading cymem-2.0.13-cp312-cp312-win_amd64.whl (40 kB)
# Downloading huggingface_hub-1.9.0-py3-none-any.whl (637 kB)
#    ---------------------------------------- 0.0/637.4 kB ? eta -:--:--
#    ---------------------------------------- 637.4/637.4 kB 3.4 MB/s eta 0:00:00
# Downloading multiprocess-0.70.19-py312-none-any.whl (150 kB)
# Downloading dill-0.4.1-py3-none-any.whl (120 kB)
# Downloading murmurhash-1.0.15-cp312-cp312-win_amd64.whl (25 kB)
# Downloading preshed-3.0.13-cp312-cp312-win_amd64.whl (122 kB)
# Downloading pyarrow-23.0.1-cp312-cp312-win_amd64.whl (27.6 MB)
#    ---------------------------------------- 0.0/27.6 MB ? eta -:--:--
#     --------------------------------------- 0.5/27.6 MB 4.2 MB/s eta 0:00:07
#    - -------------------------------------- 1.3/27.6 MB 3.7 MB/s eta 0:00:08
#    --- ------------------------------------ 2.1/27.6 MB 3.6 MB/s eta 0:00:08
#    ---- ----------------------------------- 2.9/27.6 MB 3.6 MB/s eta 0:00:07
#    ----- ---------------------------------- 3.7/27.6 MB 3.6 MB/s eta 0:00:07
#    ------ --------------------------------- 4.5/27.6 MB 3.6 MB/s eta 0:00:07
#    ------- -------------------------------- 5.2/27.6 MB 3.6 MB/s eta 0:00:07
#    -------- ------------------------------- 6.0/27.6 MB 3.6 MB/s eta 0:00:06
#    --------- ------------------------------ 6.6/27.6 MB 3.6 MB/s eta 0:00:06
#    ---------- ----------------------------- 7.3/27.6 MB 3.6 MB/s eta 0:00:06
#    ----------- ---------------------------- 8.1/27.6 MB 3.6 MB/s eta 0:00:06
#    ------------ --------------------------- 8.9/27.6 MB 3.6 MB/s eta 0:00:06
#    -------------- ------------------------- 9.7/27.6 MB 3.6 MB/s eta 0:00:05
#    --------------- ------------------------ 10.5/27.6 MB 3.6 MB/s eta 0:00:05
#    --------------- ------------------------ 11.0/27.6 MB 3.6 MB/s eta 0:00:05
#    ----------------- ---------------------- 11.8/27.6 MB 3.6 MB/s eta 0:00:05
#    ------------------ --------------------- 12.6/27.6 MB 3.6 MB/s eta 0:00:05
#    ------------------- -------------------- 13.4/27.6 MB 3.6 MB/s eta 0:00:04
#    -------------------- ------------------- 14.2/27.6 MB 3.6 MB/s eta 0:00:04
#    --------------------- ------------------ 14.9/27.6 MB 3.6 MB/s eta 0:00:04
#    ---------------------- ----------------- 15.7/27.6 MB 3.6 MB/s eta 0:00:04
#    ----------------------- ---------------- 16.5/27.6 MB 3.6 MB/s eta 0:00:04
#    ------------------------- -------------- 17.3/27.6 MB 3.6 MB/s eta 0:00:03
#    ------------------------- -------------- 17.8/27.6 MB 3.6 MB/s eta 0:00:03
#    -------------------------- ------------- 18.6/27.6 MB 3.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 19.4/27.6 MB 3.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 20.2/27.6 MB 3.6 MB/s eta 0:00:03
#    ------------------------------ --------- 21.0/27.6 MB 3.6 MB/s eta 0:00:02
#    ------------------------------- -------- 21.8/27.6 MB 3.6 MB/s eta 0:00:02
#    -------------------------------- ------- 22.3/27.6 MB 3.6 MB/s eta 0:00:02
#    --------------------------------- ------ 23.1/27.6 MB 3.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 23.9/27.6 MB 3.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 24.6/27.6 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 25.4/27.6 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 26.2/27.6 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  27.0/27.6 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 27.6/27.6 MB 3.6 MB/s eta 0:00:00
# Downloading regex-2026.4.4-cp312-cp312-win_amd64.whl (277 kB)
# Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.3-cp312-cp312-win_amd64.whl (652 kB)
#    ---------------------------------------- 0.0/652.5 kB ? eta -:--:--
#    ---------------------------------------- 652.5/652.5 kB 3.5 MB/s eta 0:00:00
# Downloading thinc-8.3.13-cp312-cp312-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 4.2 MB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 3.5 MB/s eta 0:00:00
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-1.0.0-py3-none-any.whl (50 kB)
# Downloading bitarray-3.8.1-cp312-cp312-win_amd64.whl (150 kB)
# Downloading ninja-1.13.0-py3-none-win_amd64.whl (309 kB)
# Downloading optuna-4.8.0-py3-none-any.whl (419 kB)
# Downloading structlog-25.5.0-py3-none-any.whl (72 kB)
# Downloading alembic-1.18.4-py3-none-any.whl (263 kB)
# Downloading blis-1.3.3-cp312-cp312-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.2 MB 3.4 MB/s eta 0:00:02
#    -------- ------------------------------- 1.3/6.2 MB 3.5 MB/s eta 0:00:02
#    ------------- -------------------------- 2.1/6.2 MB 3.6 MB/s eta 0:00:02
#    ------------------ --------------------- 2.9/6.2 MB 3.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 3.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.5/6.2 MB 3.6 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.2 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 5.8/6.2 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 3.6 MB/s eta 0:00:00
# Downloading cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.7 MB 3.4 MB/s eta 0:00:01
#    -------------- ------------------------- 1.3/3.7 MB 3.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.1/3.7 MB 3.7 MB/s eta 0:00:01
#    ------------------------------- -------- 2.9/3.7 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.7 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 3.6 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading webcolors-25.10.0-py3-none-any.whl (14 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py): started
#   Building wheel for wget (setup.py): finished with status 'done'
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9680 sha256=de5fb1f6886b50c20002e9a4123ae840714c9f39029ef3ea52ca64484728fe40
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\01\46\3b\e29ffbe4ebe614ff224bad40fc6a5773a67a163251585a13a9
# Successfully built wget
# Installing collected packages: wget, bitarray, webcolors, wasabi, uri-template, structlog, spacy-loggers, spacy-legacy, safetensors, regex, pyarrow, ninja, murmurhash, Mako, hf-xet, fqdn, dill, cymem, confection, colorlog, cloudpathlib, catalogue, blis, srsly, preshed, multiprocess, alembic, thinc, optuna, openai, isoduration, weasel, huggingface-hub, spacy, datasets, transformers, dspy-ai, colbert-ai
#   Attempting uninstall: regex
#     Found existing installation: regex 2024.9.11
#     Uninstalling regex-2024.9.11:
#       Successfully uninstalled regex-2024.9.11
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 16.1.0
#     Uninstalling pyarrow-16.1.0:
#       Successfully uninstalled pyarrow-16.1.0
#   Attempting uninstall: hf-xet
#     Found existing installation: hf-xet 1.2.0
#     Uninstalling hf-xet-1.2.0:
#       Successfully uninstalled hf-xet-1.2.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.8
#     Uninstalling dill-0.3.8:
#       Successfully uninstalled dill-0.3.8
#   Attempting uninstall: openai
#     Found existing installation: openai 2.15.0
#     Uninstalling openai-2.15.0:
#       Successfully uninstalled openai-2.15.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.3.2
#     Uninstalling huggingface_hub-1.3.2:
#       Successfully uninstalled huggingface_hub-1.3.2
# Successfully installed Mako-1.3.10 alembic-1.18.4 bitarray-3.8.1 blis-1.3.3 catalogue-2.0.10 cloudpathlib-0.23.0 colbert-ai-0.2.22 colorlog-6.10.1 confection-1.3.3 cymem-2.0.13 datasets-4.8.4 dill-0.4.1 dspy-ai-2.4.13 fqdn-1.5.1 hf-xet-1.4.3 huggingface-hub-1.9.0 isoduration-20.11.0 multiprocess-0.70.19 murmurhash-1.0.15 ninja-1.13.0 openai-1.61.1 optuna-4.8.0 preshed-3.0.13 pyarrow-23.0.1 regex-2026.4.4 safetensors-0.7.0 spacy-3.8.14 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.3 structlog-25.5.0 thinc-8.3.13 transformers-5.5.0 uri-template-1.3.0 wasabi-1.1.3 weasel-1.0.0 webcolors-25.10.0 wget-3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-openai 1.1.7 requires openai<3.0.0,>=1.109.1, but you have openai 1.61.1 which is incompatible.
# streamlit 1.37.1 requires protobuf<6,>=3.20, but you have protobuf 6.33.4 which is incompatible.

# %%
from datasets import load_dataset
import os
import dspy
import warnings

from dotenv import load_dotenv

# %% [markdown]
# ### OpenAI set-up

# %%
from openai import OpenAI

# %%
os.environ["DSP_NOTEBOOK_CACHEDIR"] = os.path.join(root_path, 'cache')


load_dotenv()

openai_key = os.getenv('OPENAI_API_KEY')

# %% [markdown]
# ### ColBERT set-up

# %% [markdown]
# #### Pretrained ColBERT parameters

# %% [markdown]
# For this set-up phase, we first download pretrained ColBERT parameters:

# %%
if not os.path.exists(os.path.join("data", "openqa", "colbertv2.0.tar.gz")):
    # !mkdir -p data/openqa
    
    # !wget https://downloads.cs.stanford.edu/nlp/data/colbert/colbertv2/colbertv2.0.tar.gz -P data/openqa/
    # !tar -xvzf data/openqa/colbertv2.0.tar.gz -C data/openqa/
# Out:
# The syntax of the command is incorrect.
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# tar: Error opening archive: Failed to open 'data/openqa/colbertv2.0.tar.gz'

# %% [markdown]
# If something went wrong with the above, you can just download the file https://downloads.cs.stanford.edu/nlp/data/colbert/colbertv2/colbertv2.0.tar.gz, unarchive it, and move the resulting `colbertv2.0` directory into the `data/openqa` directory.

# %% [markdown]
# #### Prebuilt ColBERT index

# %% [markdown]
# Then we download a prebuilt index that covers the domain of our task:

# %%
index_home = os.path.join("experiments", "notebook", "indexes", "cs224u.collection.2bits")

# %%
if not os.path.exists(index_home):
    # !wget https://web.stanford.edu/class/cs224u/data/cs224u.collection.2bits.tgz -P experiments/notebook/indexes
    # !tar -xvzf experiments/notebook/indexes/cs224u.collection.2bits.tgz -C experiments/notebook/indexes
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# tar: Error opening archive: Failed to open 'experiments/notebook/indexes/cs224u.collection.2bits.tgz'

# %% [markdown]
# If something went wrong with the above, download the file https://web.stanford.edu/class/cs224u/data/cs224u.collection.2bits.tgz, unarchive it, and move the resulting `cs224u.collection.2bits` directory into the `experiments/notebook/indexes` directory (which you will probably need to create).

# %% [markdown]
# #### ColBERT server

# %% [markdown]
# The final step for ColBERT is to create a local retriever for use with DSPy. The preferred method for doing this is with a seperate server.
#
# __Local usage__: If you are working with this notebook locally and a having a CUDA based device, make sure you have the [CUDA Toolkit](https://developer.nvidia.com/cuda-downloads) installed to be able to serve it on GPU. Otherwise you would need to run it on CPU. The next steps are for GPU usage.
# Open a new terminal window, navigate to the same directory as this notebook, and enter the following code:
#
# ```
# conda activate nlu
# git clone https://github.com/stanford-futuredata/ColBERT/ ;
# export INDEX_ROOT=experiments/notebook/indexes/cs224u.collection.2bits/ ;
# export INDEX_HOME=cs224u.collection.2bits ;
# export PORT=8888 ;
# python ColBERT/server.py
# ```
#
# This will start the server and you should be all set.
#
# __Colab usage__: If you are working in a Colab _and you have a Pro account_, you can open a terminal from the lower left corner of the interface and then paste in the above code. If you don't have a Pro account, then it should work to uncomment the code in the following cell and run it:

# %%
#os.environ["INDEX_ROOT"] = "experiments/notebook/indexes/cs224u.collection.2bits/"
#os.environ["INDEX_HOME"] = "cs224u.collection.2bits"
#os.environ["PORT"] = "8888"

#!git clone https://github.com/stanford-futuredata/ColBERT/

#!nohup python ColBERT/server.py &

# %% [markdown]
# This will take a minute to get started, and you won't get feedback on its progress, unfortunately. You can check that a server is running:

# %%
# !ps aux | grep server.py
# Out:
# 'grep' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# You should see a mention of `ColBERT/server.py` in the output.
#
# Assuming the server is now running, we can connect to it:
#
# *Note*: if the ColBERT server is running on a separate server, you can update `127.0.0.1` with the server's IP address.

# %%
rm = dspy.ColBERTv2(url="http://127.0.0.1:8888/api/search")

# %% [markdown]
# ### DSPy set-up

# %% [markdown]
# Here we establish the Language Model `lm` and Retriever Model `rm` that we will be using. The defaults for `lm` are just for development. You may want to develop using an inexpensive model and then do your final evalautions wih an expensive one. DSPy has support for a wide range of model APIs and local models.

# %%
lm = dspy.OpenAI(model='gpt-3.5-turbo', api_key=openai_key)

dspy.settings.configure(lm=lm, rm=rm)

# %% [markdown]
# Here's a command you can run to see which OpenAI models are available; OpenAI has entered into an increasingly closed mode where many older models are not available, so there are likely to be some surprises lurking here:

# %%
# client = OpenAI(api_key = openai_key)
# models = client.models.list()
# print(models)

# %% [markdown]
# ## SQuAD

# %% [markdown]
# Our core development dataset is [SQuAD](https://rajpurkar.github.io/SQuAD-explorer/). We chose this dataset because it is well-known and widely used, and it is large enough to support lots of meaningful development work, without, though, being so large as to require lots of compute power.

# %%
squad = load_dataset("squad", trust_remote_code=True)
# Out:
# `trust_remote_code` is not supported anymore.
# Please check that the Hugging Face dataset 'squad' isn't based on a loading script and remove `trust_remote_code`.
# If the dataset is based on a loading script, please ask the dataset author to remove it and convert it to a standard format like Parquet.
# README.md: 0.00B [00:00, ?B/s]
# c:\Users\USER\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\USER\.cache\huggingface\hub\datasets--squad. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# plain_text/train-00000-of-00001.parquet:   0%|          | 0.00/14.5M [00:00<?, ?B/s]
# plain_text/validation-00000-of-00001.par(…):   0%|          | 0.00/1.82M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/87599 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/10570 [00:00<?, ? examples/s]

# %% [markdown]
# The following utility just reads a SQuAD split in as a list of `dspy.Example` instances:

# %%
def get_squad_split(squad, split="validation"):
    """
    Use `split='train'` for the train split.

    Returns
    -------
    list of dspy.Example with attributes question, answer

    """
    data = zip(*[squad[split][field] for field in squad[split].features])
    exs = [dspy.Example(question=q, answer=a['text'][0]).with_inputs("question")
           for eid, title, context, q, a in data]
    return exs

# %% [markdown]
# ### SQuAD train

# %% [markdown]
# To build few-shot prompts, we will often sample SQuAD train examples, so we load that split here:

# %%
squad_train = get_squad_split(squad, split="train")

# %% [markdown]
# ### SQuAD dev

# %%
squad_dev = get_squad_split(squad)

# %% [markdown]
# ### SQuAD dev sample

# %% [markdown]
# Evaluations are expensive in this new era! Here's a small sample to use for dev assessments:

# %%
import random

random.seed(1)

dev_exs = random.sample(squad_dev, k=200)

# %% [markdown]
# ## DSPy basics

# %% [markdown]
# ### LM usage

# %% [markdown]
# Here's the most basic way to use the LM:

# %% [markdown]
# Keyword arguments to the underlying LM are passed through:

# %% [markdown]
# With `lm.inspect_history`, we can see the most recent language model calls:

# %%
_ = lm.inspect_history(n=1)

# %% [markdown]
# ### Signature-based prediction

# %% [markdown]
# In DSPy, __signatures__ are declarative statements about what we want the model to do. In the following `"question -> answer"` is the signature (the most basic QA signature one could write), and `dspy.Predict` is used to turn this into a complete QA system:

# %%
basic_predictor = dspy.Predict("question -> answer")

# %% [markdown]
# Here we use `basic_predictor`:

# %% [markdown]
# And here is the prompt that was given to the model:

# %%
_ = lm.inspect_history(n=1)

# %% [markdown]
# In many cases, we will want more control over the prompt. Writing a small custom `dspy.Signature` class is the easiest way to accomplish this. In the following, we just just tweak the initial instruction and provide some formatting guidance for the answer:

# %%
class BasicQASignature(dspy.Signature):
    __doc__ = """Answer questions with short factoid answers."""

    question = dspy.InputField()
    answer = dspy.OutputField(desc="often between 1 and 5 words")

# %%
sig_predictor = dspy.Predict(BasicQASignature)

# %%
sig_predictor(question="Which U.S. states border no U.S. states?")
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 sig_predictor(question="Which U.S. states border no U.S. states?")
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dspy\predict\predict.py:78, in Predict.__call__(self, **kwargs)
#      77 def __call__(self, **kwargs):
# ---> 78     return self.forward(**kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dspy\predict\predict.py:116, in Predict.forward(self, **kwargs)
#     114     completions = new_generate(lm, signature, dsp.Example(demos=demos, **kwargs), **config)
#     115 else:
# --> 116     completions = old_generate(demos, signature, kwargs, config, self.lm, self.stage)
#     118 pred = Prediction.from_completions(completions, signature=signature)
#     120 if kwargs.pop("_trace", True) and dsp.settings.trace is not None:
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dspy\predict\predict.py:143, in old_generate(demos, signature, kwargs, config, lm, stage)
#     140 template = signature_to_template(signature)
#     142 if lm is None:
# --> 143     x, C = dsp.generate(template, **config)(x, stage=stage)
#     144 else:
#     145     # Note: query_only=True means the instructions and examples are not included.
#     146     with dsp.settings.context(lm=lm, query_only=True):
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\primitives\predict.py:73, in _generate.<locals>.do_generate(example, stage, max_depth, original_example)
#      71 # Generate and extract the fields.
#      72 prompt = template(example)
# ---> 73 completions: list[dict[str, Any]] = generator(prompt, **kwargs)
#      74 completions: list[Example] = [template.extract(example, p) for p in completions]
#      76 # Find the completions that are most complete.
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:180, in GPT3.__call__(self, prompt, only_completed, return_sorted, **kwargs)
#     172 assert return_sorted is False, "for now"
#     174 # if kwargs.get("n", 1) > 1:
#     175 #     if self.model_type == "chat":
#     176 #         kwargs = {**kwargs}
#     177 #     else:
#     178 #         kwargs = {**kwargs, "logprobs": 5}
# --> 180 response = self.request(prompt, **kwargs)
#     182 self.log_usage(response)
#     183 choices = response["choices"]
#
# File c:\Users\USER\anaconda3\Lib\site-packages\backoff\_sync.py:105, in retry_exception.<locals>.retry(*args, **kwargs)
#      96 details = {
#      97     "target": target,
#      98     "args": args,
#    (...)
#     101     "elapsed": elapsed,
#     102 }
#     104 try:
# --> 105     ret = target(*args, **kwargs)
#     106 except exception as e:
#     107     max_tries_exceeded = (tries == max_tries_value)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:146, in GPT3.request(self, prompt, **kwargs)
#     143 if "model_type" in kwargs:
#     144     del kwargs["model_type"]
# --> 146 return self.basic_request(prompt, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:119, in GPT3.basic_request(self, prompt, **kwargs)
#     117     kwargs["messages"] = messages
#     118     kwargs = {"stringify_request": json.dumps(kwargs)}
# --> 119     response = chat_request(**kwargs)
#     121 else:
#     122     kwargs["prompt"] = prompt
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:271, in chat_request(**kwargs)
#     268 if OPENAI_LEGACY:
#     269     return _cached_gpt3_turbo_request_v2_wrapped(**kwargs)
# --> 271 return v1_cached_gpt3_turbo_request_v2_wrapped(**kwargs).model_dump()
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\cache_utils.py:16, in noop_decorator.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      14 @wraps(func)
#      15 def wrapper(*args, **kwargs):
# ---> 16     return func(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:264, in v1_cached_gpt3_turbo_request_v2_wrapped(**kwargs)
#     261 @functools.lru_cache(maxsize=None if cache_turn_on else 0)
#     262 @NotebookCacheMemory.cache
#     263 def v1_cached_gpt3_turbo_request_v2_wrapped(**kwargs):
# --> 264     return v1_cached_gpt3_turbo_request_v2(**kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\memory.py:577, in MemorizedFunc.__call__(self, *args, **kwargs)
#     575 def __call__(self, *args, **kwargs):
#     576     # Return the output, without the metadata
# --> 577     return self._cached_call(args, kwargs, shelving=False)[0]
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\memory.py:532, in MemorizedFunc._cached_call(self, args, kwargs, shelving)
#     526     self.warn(
#     527         f"Computing func {func_name}, argument hash {args_id} "
#     528         f"in location {location}"
#     529     )
#     531 # Returns the output but not the metadata
# --> 532 return self._call(call_id, args, kwargs, shelving)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\memory.py:771, in MemorizedFunc._call(self, call_id, args, kwargs, shelving)
#     769 self._before_call(args, kwargs)
#     770 start_time = time.time()
# --> 771 output = self.func(*args, **kwargs)
#     772 return self._after_call(call_id, args, kwargs, shelving,
#     773                         output, start_time)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:258, in v1_cached_gpt3_turbo_request_v2(**kwargs)
#     256 if "stringify_request" in kwargs:
#     257     kwargs = json.loads(kwargs["stringify_request"])
# --> 258 return openai.chat.completions.create(**kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\openai\_utils\_proxy.py:20, in LazyProxy.__getattr__(self, attr)
#      19 def __getattr__(self, attr: str) -> object:
# ---> 20     proxied = self.__get_proxied__()
#      21     if isinstance(proxied, LazyProxy):
#      22         return proxied  # pyright: ignore
#
# File c:\Users\USER\anaconda3\Lib\site-packages\openai\_utils\_proxy.py:55, in LazyProxy.__get_proxied__(self)
#      54 def __get_proxied__(self) -> T:
# ---> 55     return self.__load__()
#
# File c:\Users\USER\anaconda3\Lib\site-packages\openai\_module_client.py:12, in ChatProxy.__load__(self)
#      10 @override
#      11 def __load__(self) -> resources.Chat:
# ---> 12     return _load_client().chat
#
# File c:\Users\USER\anaconda3\Lib\site-packages\openai\__init__.py:329, in _load_client()
#     313         _client = _AzureModuleClient(  # type: ignore
#     314             api_version=api_version,
#     315             azure_endpoint=azure_endpoint,
#    (...)
#     325             http_client=http_client,
#     326         )
#     327         return _client
# --> 329     _client = _ModuleClient(
#     330         api_key=api_key,
#     331         organization=organization,
#     332         project=project,
#     333         base_url=base_url,
#     334         timeout=timeout,
#     335         max_retries=max_retries,
#     336         default_headers=default_headers,
#     337         default_query=default_query,
#     338         http_client=http_client,
#     339     )
#     340     return _client
#     342 return _client
#
# File c:\Users\USER\anaconda3\Lib\site-packages\openai\_client.py:110, in OpenAI.__init__(self, api_key, organization, project, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     108     api_key = os.environ.get("OPENAI_API_KEY")
#     109 if api_key is None:
# --> 110     raise OpenAIError(
#     111         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     112     )
#     113 self.api_key = api_key
#     115 if organization is None:
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
_ = lm.inspect_history(n=1)

# %% [markdown]
# ### Modules

# %% [markdown]
# One of the hallmarks of DSPy is that it adopts design patterns from PyTorch. The main example of this is DSPy's use of the `Module` as the basic unit for writing simple and complex programs. Here is a very basic module for QA that makes use of `BasicQASignature` as we defined it just above.

# %%
class BasicQA(dspy.Module):
    def __init__(self):
        super().__init__()
        self.generate_answer = dspy.Predict(BasicQASignature)

    def forward(self, question):
        return self.generate_answer(question=question)

# %% [markdown]
# As with PyTorch, the `forward` method is called when we want to make predictions:

# %%
basic_qa_model = BasicQA()

# %%
basic_qa_model(question="What is the birthplace of the first author to win a Hugo Award for a translation?")
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 basic_qa_model(question="What is the birthplace of the first author to win a Hugo Award for a translation?")
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dspy\primitives\program.py:26, in Module.__call__(self, *args, **kwargs)
#      25 def __call__(self, *args, **kwargs):
# ---> 26     return self.forward(*args, **kwargs)
#
# Cell In[27], line 7, in BasicQA.forward(self, question)
#       6 def forward(self, question):
# ----> 7     return self.generate_answer(question=question)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dspy\predict\predict.py:78, in Predict.__call__(self, **kwargs)
#      77 def __call__(self, **kwargs):
# ---> 78     return self.forward(**kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dspy\predict\predict.py:116, in Predict.forward(self, **kwargs)
#     114     completions = new_generate(lm, signature, dsp.Example(demos=demos, **kwargs), **config)
#     115 else:
# --> 116     completions = old_generate(demos, signature, kwargs, config, self.lm, self.stage)
#     118 pred = Prediction.from_completions(completions, signature=signature)
#     120 if kwargs.pop("_trace", True) and dsp.settings.trace is not None:
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dspy\predict\predict.py:143, in old_generate(demos, signature, kwargs, config, lm, stage)
#     140 template = signature_to_template(signature)
#     142 if lm is None:
# --> 143     x, C = dsp.generate(template, **config)(x, stage=stage)
#     144 else:
#     145     # Note: query_only=True means the instructions and examples are not included.
#     146     with dsp.settings.context(lm=lm, query_only=True):
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\primitives\predict.py:73, in _generate.<locals>.do_generate(example, stage, max_depth, original_example)
#      71 # Generate and extract the fields.
#      72 prompt = template(example)
# ---> 73 completions: list[dict[str, Any]] = generator(prompt, **kwargs)
#      74 completions: list[Example] = [template.extract(example, p) for p in completions]
#      76 # Find the completions that are most complete.
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:180, in GPT3.__call__(self, prompt, only_completed, return_sorted, **kwargs)
#     172 assert return_sorted is False, "for now"
#     174 # if kwargs.get("n", 1) > 1:
#     175 #     if self.model_type == "chat":
#     176 #         kwargs = {**kwargs}
#     177 #     else:
#     178 #         kwargs = {**kwargs, "logprobs": 5}
# --> 180 response = self.request(prompt, **kwargs)
#     182 self.log_usage(response)
#     183 choices = response["choices"]
#
# File c:\Users\USER\anaconda3\Lib\site-packages\backoff\_sync.py:105, in retry_exception.<locals>.retry(*args, **kwargs)
#      96 details = {
#      97     "target": target,
#      98     "args": args,
#    (...)
#     101     "elapsed": elapsed,
#     102 }
#     104 try:
# --> 105     ret = target(*args, **kwargs)
#     106 except exception as e:
#     107     max_tries_exceeded = (tries == max_tries_value)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:146, in GPT3.request(self, prompt, **kwargs)
#     143 if "model_type" in kwargs:
#     144     del kwargs["model_type"]
# --> 146 return self.basic_request(prompt, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:119, in GPT3.basic_request(self, prompt, **kwargs)
#     117     kwargs["messages"] = messages
#     118     kwargs = {"stringify_request": json.dumps(kwargs)}
# --> 119     response = chat_request(**kwargs)
#     121 else:
#     122     kwargs["prompt"] = prompt
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:271, in chat_request(**kwargs)
#     268 if OPENAI_LEGACY:
#     269     return _cached_gpt3_turbo_request_v2_wrapped(**kwargs)
# --> 271 return v1_cached_gpt3_turbo_request_v2_wrapped(**kwargs).model_dump()
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\cache_utils.py:16, in noop_decorator.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      14 @wraps(func)
#      15 def wrapper(*args, **kwargs):
# ---> 16     return func(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:264, in v1_cached_gpt3_turbo_request_v2_wrapped(**kwargs)
#     261 @functools.lru_cache(maxsize=None if cache_turn_on else 0)
#     262 @NotebookCacheMemory.cache
#     263 def v1_cached_gpt3_turbo_request_v2_wrapped(**kwargs):
# --> 264     return v1_cached_gpt3_turbo_request_v2(**kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\memory.py:577, in MemorizedFunc.__call__(self, *args, **kwargs)
#     575 def __call__(self, *args, **kwargs):
#     576     # Return the output, without the metadata
# --> 577     return self._cached_call(args, kwargs, shelving=False)[0]
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\memory.py:532, in MemorizedFunc._cached_call(self, args, kwargs, shelving)
#     526     self.warn(
#     527         f"Computing func {func_name}, argument hash {args_id} "
#     528         f"in location {location}"
#     529     )
#     531 # Returns the output but not the metadata
# --> 532 return self._call(call_id, args, kwargs, shelving)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\memory.py:771, in MemorizedFunc._call(self, call_id, args, kwargs, shelving)
#     769 self._before_call(args, kwargs)
#     770 start_time = time.time()
# --> 771 output = self.func(*args, **kwargs)
#     772 return self._after_call(call_id, args, kwargs, shelving,
#     773                         output, start_time)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:258, in v1_cached_gpt3_turbo_request_v2(**kwargs)
#     256 if "stringify_request" in kwargs:
#     257     kwargs = json.loads(kwargs["stringify_request"])
# --> 258 return openai.chat.completions.create(**kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\openai\_utils\_proxy.py:20, in LazyProxy.__getattr__(self, attr)
#      19 def __getattr__(self, attr: str) -> object:
# ---> 20     proxied = self.__get_proxied__()
#      21     if isinstance(proxied, LazyProxy):
#      22         return proxied  # pyright: ignore
#
# File c:\Users\USER\anaconda3\Lib\site-packages\openai\_utils\_proxy.py:55, in LazyProxy.__get_proxied__(self)
#      54 def __get_proxied__(self) -> T:
# ---> 55     return self.__load__()
#
# File c:\Users\USER\anaconda3\Lib\site-packages\openai\_module_client.py:12, in ChatProxy.__load__(self)
#      10 @override
#      11 def __load__(self) -> resources.Chat:
# ---> 12     return _load_client().chat
#
# File c:\Users\USER\anaconda3\Lib\site-packages\openai\__init__.py:329, in _load_client()
#     313         _client = _AzureModuleClient(  # type: ignore
#     314             api_version=api_version,
#     315             azure_endpoint=azure_endpoint,
#    (...)
#     325             http_client=http_client,
#     326         )
#     327         return _client
# --> 329     _client = _ModuleClient(
#     330         api_key=api_key,
#     331         organization=organization,
#     332         project=project,
#     333         base_url=base_url,
#     334         timeout=timeout,
#     335         max_retries=max_retries,
#     336         default_headers=default_headers,
#     337         default_query=default_query,
#     338         http_client=http_client,
#     339     )
#     340     return _client
#     342 return _client
#
# File c:\Users\USER\anaconda3\Lib\site-packages\openai\_client.py:110, in OpenAI.__init__(self, api_key, organization, project, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     108     api_key = os.environ.get("OPENAI_API_KEY")
#     109 if api_key is None:
# --> 110     raise OpenAIError(
#     111         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     112     )
#     113 self.api_key = api_key
#     115 if organization is None:
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %% [markdown]
# The modular design of DSPy starts to become apparent now. If you want to change the above to use chain of thought instead of regular predictions, you need only change `dspy.Predict` to `dspy.ChainOfThought`, and similarly for `dspy.ReAct`, `dspy.ProgramOfThought`, or a module you wrote yourself.

# %% [markdown]
# ### Optimizing

# %% [markdown]
# The QA system we've defined so far is a zero-shot system. To change it into a few-shot system, we will rely on a DSPy optimizer (__teleprompter__). This will allow us to flexibly move between the zero-shot and few-shot formulations. The following code achieves this.

# %%
from dspy.teleprompt import LabeledFewShot
# Out:
# dspy\cache\compiler

# %% [markdown]
# Here we instantiate a `LabeledFewShot` teleprompter that will add three demonstrations. These will be sampled randomly from the set of train examples we provide:

# %%
fewshot_teleprompter = LabeledFewShot(k=3)

# %% [markdown]
# And then we call `compile` on `basic_qa_model` as we defined it above. This returns a new module that we use like any other in DSPy:

# %%
basic_fewshot_qa_model = fewshot_teleprompter.compile(basic_qa_model, trainset=squad_train)

# %%
basic_fewshot_qa_model(question="What is the birthplace of the first author to win a Hugo Award for a translation?")
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 basic_fewshot_qa_model(question="What is the birthplace of the first author to win a Hugo Award for a translation?")
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dspy\primitives\program.py:26, in Module.__call__(self, *args, **kwargs)
#      25 def __call__(self, *args, **kwargs):
# ---> 26     return self.forward(*args, **kwargs)
#
# Cell In[27], line 7, in BasicQA.forward(self, question)
#       6 def forward(self, question):
# ----> 7     return self.generate_answer(question=question)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dspy\predict\predict.py:78, in Predict.__call__(self, **kwargs)
#      77 def __call__(self, **kwargs):
# ---> 78     return self.forward(**kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dspy\predict\predict.py:116, in Predict.forward(self, **kwargs)
#     114     completions = new_generate(lm, signature, dsp.Example(demos=demos, **kwargs), **config)
#     115 else:
# --> 116     completions = old_generate(demos, signature, kwargs, config, self.lm, self.stage)
#     118 pred = Prediction.from_completions(completions, signature=signature)
#     120 if kwargs.pop("_trace", True) and dsp.settings.trace is not None:
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dspy\predict\predict.py:143, in old_generate(demos, signature, kwargs, config, lm, stage)
#     140 template = signature_to_template(signature)
#     142 if lm is None:
# --> 143     x, C = dsp.generate(template, **config)(x, stage=stage)
#     144 else:
#     145     # Note: query_only=True means the instructions and examples are not included.
#     146     with dsp.settings.context(lm=lm, query_only=True):
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\primitives\predict.py:73, in _generate.<locals>.do_generate(example, stage, max_depth, original_example)
#      71 # Generate and extract the fields.
#      72 prompt = template(example)
# ---> 73 completions: list[dict[str, Any]] = generator(prompt, **kwargs)
#      74 completions: list[Example] = [template.extract(example, p) for p in completions]
#      76 # Find the completions that are most complete.
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:180, in GPT3.__call__(self, prompt, only_completed, return_sorted, **kwargs)
#     172 assert return_sorted is False, "for now"
#     174 # if kwargs.get("n", 1) > 1:
#     175 #     if self.model_type == "chat":
#     176 #         kwargs = {**kwargs}
#     177 #     else:
#     178 #         kwargs = {**kwargs, "logprobs": 5}
# --> 180 response = self.request(prompt, **kwargs)
#     182 self.log_usage(response)
#     183 choices = response["choices"]
#
# File c:\Users\USER\anaconda3\Lib\site-packages\backoff\_sync.py:105, in retry_exception.<locals>.retry(*args, **kwargs)
#      96 details = {
#      97     "target": target,
#      98     "args": args,
#    (...)
#     101     "elapsed": elapsed,
#     102 }
#     104 try:
# --> 105     ret = target(*args, **kwargs)
#     106 except exception as e:
#     107     max_tries_exceeded = (tries == max_tries_value)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:146, in GPT3.request(self, prompt, **kwargs)
#     143 if "model_type" in kwargs:
#     144     del kwargs["model_type"]
# --> 146 return self.basic_request(prompt, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:119, in GPT3.basic_request(self, prompt, **kwargs)
#     117     kwargs["messages"] = messages
#     118     kwargs = {"stringify_request": json.dumps(kwargs)}
# --> 119     response = chat_request(**kwargs)
#     121 else:
#     122     kwargs["prompt"] = prompt
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:271, in chat_request(**kwargs)
#     268 if OPENAI_LEGACY:
#     269     return _cached_gpt3_turbo_request_v2_wrapped(**kwargs)
# --> 271 return v1_cached_gpt3_turbo_request_v2_wrapped(**kwargs).model_dump()
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\cache_utils.py:16, in noop_decorator.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      14 @wraps(func)
#      15 def wrapper(*args, **kwargs):
# ---> 16     return func(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:264, in v1_cached_gpt3_turbo_request_v2_wrapped(**kwargs)
#     261 @functools.lru_cache(maxsize=None if cache_turn_on else 0)
#     262 @NotebookCacheMemory.cache
#     263 def v1_cached_gpt3_turbo_request_v2_wrapped(**kwargs):
# --> 264     return v1_cached_gpt3_turbo_request_v2(**kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\memory.py:577, in MemorizedFunc.__call__(self, *args, **kwargs)
#     575 def __call__(self, *args, **kwargs):
#     576     # Return the output, without the metadata
# --> 577     return self._cached_call(args, kwargs, shelving=False)[0]
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\memory.py:532, in MemorizedFunc._cached_call(self, args, kwargs, shelving)
#     526     self.warn(
#     527         f"Computing func {func_name}, argument hash {args_id} "
#     528         f"in location {location}"
#     529     )
#     531 # Returns the output but not the metadata
# --> 532 return self._call(call_id, args, kwargs, shelving)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\memory.py:771, in MemorizedFunc._call(self, call_id, args, kwargs, shelving)
#     769 self._before_call(args, kwargs)
#     770 start_time = time.time()
# --> 771 output = self.func(*args, **kwargs)
#     772 return self._after_call(call_id, args, kwargs, shelving,
#     773                         output, start_time)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:258, in v1_cached_gpt3_turbo_request_v2(**kwargs)
#     256 if "stringify_request" in kwargs:
#     257     kwargs = json.loads(kwargs["stringify_request"])
# --> 258 return openai.chat.completions.create(**kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\openai\_utils\_proxy.py:20, in LazyProxy.__getattr__(self, attr)
#      19 def __getattr__(self, attr: str) -> object:
# ---> 20     proxied = self.__get_proxied__()
#      21     if isinstance(proxied, LazyProxy):
#      22         return proxied  # pyright: ignore
#
# File c:\Users\USER\anaconda3\Lib\site-packages\openai\_utils\_proxy.py:55, in LazyProxy.__get_proxied__(self)
#      54 def __get_proxied__(self) -> T:
# ---> 55     return self.__load__()
#
# File c:\Users\USER\anaconda3\Lib\site-packages\openai\_module_client.py:12, in ChatProxy.__load__(self)
#      10 @override
#      11 def __load__(self) -> resources.Chat:
# ---> 12     return _load_client().chat
#
# File c:\Users\USER\anaconda3\Lib\site-packages\openai\__init__.py:329, in _load_client()
#     313         _client = _AzureModuleClient(  # type: ignore
#     314             api_version=api_version,
#     315             azure_endpoint=azure_endpoint,
#    (...)
#     325             http_client=http_client,
#     326         )
#     327         return _client
# --> 329     _client = _ModuleClient(
#     330         api_key=api_key,
#     331         organization=organization,
#     332         project=project,
#     333         base_url=base_url,
#     334         timeout=timeout,
#     335         max_retries=max_retries,
#     336         default_headers=default_headers,
#     337         default_query=default_query,
#     338         http_client=http_client,
#     339     )
#     340     return _client
#     342 return _client
#
# File c:\Users\USER\anaconda3\Lib\site-packages\openai\_client.py:110, in OpenAI.__init__(self, api_key, organization, project, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     108     api_key = os.environ.get("OPENAI_API_KEY")
#     109 if api_key is None:
# --> 110     raise OpenAIError(
#     111         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     112     )
#     113 self.api_key = api_key
#     115 if organization is None:
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %% [markdown]
# With `inspect_history`, we can see that prompts now contain demonstrations:

# %%
_ = lm.inspect_history(n=1)

# %% [markdown]
# ### Evaluation

# %% [markdown]
# Our evaluation metric is a standard one for SQuAD and related tasks: exact match of the answer (EM).

# %%
from dspy.evaluate import answer_exact_match
from dspy.evaluate.evaluate import Evaluate

# %%
answer_exact_match(dspy.Example(answer="STAGE 2!"), dspy.Prediction(answer="stage 2"))

# %% [markdown]
# In DSPy, `Evaluate` objects provide a uniform interface for running evaluations. Here are two for us to use in development. The first will evaluate on all of `dev_exs` and should provide a meaningful picture of how a system is doing. It could be expensive to use it a lot, though. The second is for debugging and is probably too small to give a reliable estimate.

# %%
dev_evaluater = Evaluate(
    devset=dev_exs, # 200 examples
    num_threads=1,
    display_progress=True,
    display_table=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 dev_evaluater = Evaluate(
#       2     devset=dev_exs, # 200 examples
#       3     num_threads=1,
#       4     display_progress=True,
#       5     display_table=5)
#
# NameError: name 'Evaluate' is not defined

# %%
tiny_evaluater = Evaluate(
    devset=dev_exs[: 15],
    num_threads=1,
    display_progress=True,
    display_table=5)

# %% [markdown]
# Here is a tiny (debugging-oriented) evaluation of our few-shot QA sytem:

# %%
tiny_evaluater(basic_fewshot_qa_model, metric=answer_exact_match)

# %% [markdown]
# ### Retrieval

# %% [markdown]
# The final major component of our systems is retrieval. When we defined `rm`, we connected to a remote ColBERT index and retriever system that we can now use for search.

# %% [markdown]
# The basic `dspy.retrieve` method returns only passages:

# %%
retriever = dspy.Retrieve(k=3)

# %%
passages = retriever("What is the birthplace of the first author to win a Hugo Award for a translation?")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\USER\anaconda3\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\USER\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\USER\anaconda3\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\Users\USER\anaconda3\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 passages = retriever("What is the birthplace of the first author to win a Hugo Award for a translation?")
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dspy\retrieve\retrieve.py:40, in Retrieve.__call__(self, *args, **kwargs)
#      39 def __call__(self, *args, **kwargs):
# ---> 40     return self.forward(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dspy\retrieve\retrieve.py:69, in Retrieve.forward(self, query_or_queries, k, by_prob, with_metadata, **kwargs)
#      67 k = k if k is not None else self.k
#      68 if not with_metadata:
# ---> 69     passages = dsp.retrieveEnsemble(queries, k=k, by_prob=by_prob, **kwargs)
#      70     return Prediction(passages=passages)
#      71 else:
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\primitives\search.py:93, in retrieveEnsemble(queries, k, by_prob, **kwargs)
#      90 queries = [q for q in queries if q]
#      92 if len(queries) == 1:
# ---> 93     return retrieve(queries[0], k, **kwargs)
#      95 passages = {}
#      96 for q in queries:
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\primitives\search.py:14, in retrieve(query, k, **kwargs)
#      12 if not dsp.settings.rm:
#      13     raise AssertionError("No RM is loaded.")
# ---> 14 passages = dsp.settings.rm(query, k=k, **kwargs)
#      15 if not isinstance(passages, Iterable):
#      16     # it's not an iterable yet; make it one.
#      17     # TODO: we should unify the type signatures of dspy.Retriever
#      18     passages = [passages]
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\colbertv2.py:30, in ColBERTv2.__call__(self, query, k, simplify)
#      28     topk: list[dict[str, Any]] = colbertv2_post_request(self.url, query, k)
#      29 else:
# ---> 30     topk: list[dict[str, Any]] = colbertv2_get_request(self.url, query, k)
#      32 if simplify:
#      33     return [psg["long_text"] for psg in topk]
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\cache_utils.py:16, in noop_decorator.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      14 @wraps(func)
#      15 def wrapper(*args, **kwargs):
# ---> 16     return func(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\colbertv2.py:55, in colbertv2_get_request_v2_wrapped(*args, **kwargs)
#      52 @functools.cache
#      53 @NotebookCacheMemory.cache
#      54 def colbertv2_get_request_v2_wrapped(*args, **kwargs):
# ---> 55     return colbertv2_get_request_v2(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\memory.py:577, in MemorizedFunc.__call__(self, *args, **kwargs)
#     575 def __call__(self, *args, **kwargs):
#     576     # Return the output, without the metadata
# --> 577     return self._cached_call(args, kwargs, shelving=False)[0]
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\memory.py:532, in MemorizedFunc._cached_call(self, args, kwargs, shelving)
#     526     self.warn(
#     527         f"Computing func {func_name}, argument hash {args_id} "
#     528         f"in location {location}"
#     529     )
#     531 # Returns the output but not the metadata
# --> 532 return self._call(call_id, args, kwargs, shelving)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\memory.py:771, in MemorizedFunc._call(self, call_id, args, kwargs, shelving)
#     769 self._before_call(args, kwargs)
#     770 start_time = time.time()
# --> 771 output = self.func(*args, **kwargs)
#     772 return self._after_call(call_id, args, kwargs, shelving,
#     773                         output, start_time)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\colbertv2.py:47, in colbertv2_get_request_v2(url, query, k)
#      44 payload = {"query": query, "k": k}
#      45 res = requests.get(url, params=payload, timeout=10)
# ---> 47 topk = res.json()["topk"][:k]
#      48 topk = [{**d, "long_text": d["text"]} for d in topk]
#      49 return topk[:k]
#
# File c:\Users\USER\anaconda3\Lib\site-packages\requests\models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
passages.passages[0]

# %% [markdown]
# If we need passages with scores and other metadata, we can call `rm` directly:

# %%
rm("What is the birthplace of the first author to win a Hugo Award for a translation?", k=1)

# %% [markdown]
# ## Few-shot OpenQA with context

# %% [markdown]
# Let's build on the above core concepts to define a basic retrieval-augmented generation (RAG) program. This program solves the core task of few-shot OpenQA task and will serve as the basis for the homework questions:

# %% [markdown]
# We begin with a signature that takes context into account but is otherwise just like `BasicQASignature` above:

# %%
class ContextQASignature(dspy.Signature):
    __doc__ = """Answer questions with short factoid answers."""

    context = dspy.InputField(desc="may contain relevant facts")
    question = dspy.InputField()
    answer = dspy.OutputField(desc="often between 1 and 5 words")

# %% [markdown]
# And here is a complete program/system for the task:

# %%
class RAG(dspy.Module):
    def __init__(self, num_passages=1):
        super().__init__()
        self.retrieve = dspy.Retrieve(k=num_passages)
        self.generate_answer = dspy.Predict(ContextQASignature)

    def forward(self, question):
        context = self.retrieve(question).passages
        prediction = self.generate_answer(context=context, question=question)
        return dspy.Prediction(context=context, answer=prediction.answer)

# %%
rag_model = RAG(num_passages=3)

# %%
rag_model(question="What is the birthplace of the first author to win a Hugo Award for a translation?")

# %% [markdown]
# An optional tiny evaluation:

# %%
tiny_evaluater(rag_model, metric=answer_exact_match)

# %% [markdown]
# ## Question 1: Optimizing RAG [2 points]

# %% [markdown]
# We used `RAG` above as a zero-shot system. We could turn it into a few-shot system by using `LabeledFewShot` as we did in [the teleprompting section](#Teleprompting) above, but this may actually be problematic: if we randomly sample demonstrations with retrieved passages, we might be instructing the model with a lot of cases where the context passage isn't helping (and may actually be actively misleading the model).
#
# What we'd like to do is select demonstrations where the model gets the answer correct and the context passage does contain the answer. To do this, we will use the DSPy `BootstrapFewShot` optimizer. There are two steps for this: (1) defining a metric and (2) running the optimizer.
#
# __Note__: The code for this question can be found in the DSPy tutorials, and you should feel free to make use of that code. The goal is to help you understand the design patterns and overall logic of optimizing DSPy programs.

# %% [markdown]
# __Task 1__: Complete `validate_context_and_answer` according to the specification in the docstring.

# %%
def validate_context_and_answer(example, pred, trace=None):
    """Return True if `example.answer` matches `pred.answer` according
    to `dspy.evaluate.answer_exact_match` and `pred.context` contains
    `example.answer` according to `dspy.evaluate.answer_passage_match`.

    Parameters
    ----------
    example: dspy.Example
        with attributes `answer` and `context`
    pred: dspy.Example
        with attributes `answer` and `context`
    trace : None (included for dspy internal compatibility)

    Returns
    -------
    bool

    """
    pass
    ##### YOUR CODE HERE
def validate_context_and_answer(example, pred, trace=None):
    """Return True if `example.answer` matches `pred.answer` according
    to `dspy.evaluate.answer_exact_match` and `pred.context` contains
    `example.answer` according to `dspy.evaluate.answer_passage_match`.
    """
    
    import dspy

    exact_match = dspy.evaluate.answer_exact_match(
        example.answer, pred.answer
    )
    
    passage_match = dspy.evaluate.answer_passage_match(
        example.answer, pred.context
    )

# %% [markdown]
# A test you can use to check your implementation:

# %%
def test_validate_context_and_answer(func):
    examples = [
        (
            dspy.Example(question="Q1", answer="B"),
            dspy.Prediction(question="Q1", context="A B C", answer="B"),
            True
        ),
        # Context doesn't contain answer, but predicted answer is correct.
        (
            dspy.Example(question="Q1", answer="D"),
            dspy.Prediction(question="Q1", context="A B C", answer="D"),
            False
        ),
        # Context contains answer, but predicted answer is not correct.
        (
            dspy.Example(question="Q1", answer="C"),
            dspy.Prediction(question="Q1", context="A B C", answer="D"),
            False
        )
    ]
    errcount = 0
    for ex, pred, result in examples:
        predicted = func(ex, pred, trace=None)
        if predicted != result:
            errcount += 1
            print(f"Error for `{func.__name__}`: "
                  f"Expected inputs\n\t{ex}\n\t{pred} to return {result}.")
    if errcount == 0:
        print(f"No errors detected for `{func.__name__}`")

# %%
test_validate_context_and_answer(validate_context_and_answer)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 test_validate_context_and_answer(validate_context_and_answer)
#
# Cell In[38], line 23, in test_validate_context_and_answer(func)
#      21 errcount = 0
#      22 for ex, pred, result in examples:
# ---> 23     predicted = func(ex, pred, trace=None)
#      24     if predicted != result:
#      25         errcount += 1
#
# Cell In[37], line 29, in validate_context_and_answer(example, pred, trace)
#      22 """Return True if `example.answer` matches `pred.answer` according
#      23 to `dspy.evaluate.answer_exact_match` and `pred.context` contains
#      24 `example.answer` according to `dspy.evaluate.answer_passage_match`.
#      25 """
#      27 import dspy
# ---> 29 exact_match = dspy.evaluate.answer_exact_match(
#      30     example.answer, pred.answer
#      31 )
#      33 passage_match = dspy.evaluate.answer_passage_match(
#      34     example.answer, pred.context
#      35 )
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dspy\evaluate\metrics.py:7, in answer_exact_match(example, pred, trace, frac)
#       6 def answer_exact_match(example, pred, trace=None, frac=1.0):
# ----> 7     assert(type(example.answer) is str or type(example.answer) is list)
#       9     if type(example.answer) is str:
#      10         return dsp.answer_match(pred.answer, [example.answer], frac=frac)
#
# AttributeError: 'str' object has no attribute 'answer'

# %% [markdown]
# __Task 2__: Complete `bootstrap_optimize` according to the specification in the docstring.

# %%
from dspy.teleprompt import BootstrapFewShot

def bootstrap_optimize(model):
    """Use `BootstrapFewShot` to optimize `model`, with the metric set
    to `validate_context_and_answer` as defined above and default
    values for all other keyword arguments to `BootstrapFewShot`.

    Parameters
    ----------
    model: dspy.Module

    Returns
    -------
    dspy.Module, the optimized version of `model`

    """
    pass
    ##### YOUR CODE HERE
    from dspy.teleprompt import BootstrapFewShot

def bootstrap_optimize(model):
    """Use `BootstrapFewShot` to optimize `model`."""

    optimizer = BootstrapFewShot(
        metric=validate_context_and_answer
    )

    optimized_model = optimizer.compile(model)

    return optimized_model

# %% [markdown]
# A test you can use to check your implementation:

# %%
def test_bootstrap_optimize(func):
    model = RAG()
    compiled = func(model)
    if not hasattr(compiled, "_compiled") or not compiled._compiled:
        print(f"Error for `{func.__name__}`: "
               "The return value is not a compiled program.")
        return None
    state = compiled.dump_state()
    if not state['generate_answer']['demos']:
        print(f"Error for `{func.__name__}`: "
               "The compiled program has no `demos`.")
        return None
    print(f"No errors detected for `{func.__name__}`")

# %%
test_bootstrap_optimize(bootstrap_optimize)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 test_bootstrap_optimize(bootstrap_optimize)
#
# NameError: name 'bootstrap_optimize' is not defined

# %% [markdown]
# ## Question 2: Multi-passage summarization [2 points]

# %% [markdown]
# The `dspy.Retrieve` layer in our `RAG` retrieves `k` passages, where `k` is under the control of the user. One hypothesis one might have is that it would be good to summarize these passages before using them as evidence. This seems especially likely to help in scenarios where the question can be answered only by synthesizing information across documents – it might be too much to ask the language model to do both synthesizing and answering in a single step.
#
# The current question maps out a basic strategy for summarization. The heart of it is a new signature called `SummarizeSignature`. This can be used on its own with a simple `dspy.Predict` call, and we'll incorporate it into a RAG program in the next question.
#
# For this question, though, your task is just to complete `SummarizeSignature`. The requirements are as follows:
#
# 1. A `__doc__` value that gives an instruction that seems to work well. You can decide what to say here.
# 2. A `dspy.InputField` named `context`. You can decide whether to use the `desc` parameter.
# 3. A `dspy.OutputField` named `summary`. You can decide whether to use the `desc` parameter.

# %%
class SummarizeSignature(dspy.Signature):
    pass
    ##### YOUR CODE HERE

class SummarizeSignature(dspy.Signature):
    """Summarize the given text into a concise summary."""
    
    text = dspy.InputField(desc="The input text to summarize")
    summary = dspy.OutputField(desc="A concise summary of the input text")

# %% [markdown]
# Here's a simple test that just checks for the required pieces in a basic way:

# %%
def test_SummarizeSignature(sigclass):
    fields = sigclass.fields
    expected_fieldnames = ['context', 'summary']
    fieldnames = sorted(fields)
    errcount = 0
    if expected_fieldnames != fieldnames:
        errcount += 1
        print(f"Error for `{sigclass.__name__}`: "
              f"Expected fieldnames {expected_fieldnames}, got {fieldnames}.")
    if not sigclass.__doc__:
        errcount += 1
        print(f"Error for `{sigclass.__name__}`: No docstring specified.")
    if errcount == 0:
        print(f"No errors detected for `{sigclass.__name__}`")

# %%
test_SummarizeSignature(SummarizeSignature)
# Out:
# Error for `SummarizeSignature`: Expected fieldnames ['context', 'summary'], got ['summary', 'text'].

# %% [markdown]
# Here is the simplest way to use `SummarizeSignature`:

# %%
summarizer = dspy.Predict(SummarizeSignature)

# %%
summarizer(context=retriever("Where is Guarani spoken?").passages)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\USER\anaconda3\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\USER\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\USER\anaconda3\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\Users\USER\anaconda3\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 summarizer(context=retriever("Where is Guarani spoken?").passages)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dspy\retrieve\retrieve.py:40, in Retrieve.__call__(self, *args, **kwargs)
#      39 def __call__(self, *args, **kwargs):
# ---> 40     return self.forward(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dspy\retrieve\retrieve.py:69, in Retrieve.forward(self, query_or_queries, k, by_prob, with_metadata, **kwargs)
#      67 k = k if k is not None else self.k
#      68 if not with_metadata:
# ---> 69     passages = dsp.retrieveEnsemble(queries, k=k, by_prob=by_prob, **kwargs)
#      70     return Prediction(passages=passages)
#      71 else:
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\primitives\search.py:93, in retrieveEnsemble(queries, k, by_prob, **kwargs)
#      90 queries = [q for q in queries if q]
#      92 if len(queries) == 1:
# ---> 93     return retrieve(queries[0], k, **kwargs)
#      95 passages = {}
#      96 for q in queries:
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\primitives\search.py:14, in retrieve(query, k, **kwargs)
#      12 if not dsp.settings.rm:
#      13     raise AssertionError("No RM is loaded.")
# ---> 14 passages = dsp.settings.rm(query, k=k, **kwargs)
#      15 if not isinstance(passages, Iterable):
#      16     # it's not an iterable yet; make it one.
#      17     # TODO: we should unify the type signatures of dspy.Retriever
#      18     passages = [passages]
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\colbertv2.py:30, in ColBERTv2.__call__(self, query, k, simplify)
#      28     topk: list[dict[str, Any]] = colbertv2_post_request(self.url, query, k)
#      29 else:
# ---> 30     topk: list[dict[str, Any]] = colbertv2_get_request(self.url, query, k)
#      32 if simplify:
#      33     return [psg["long_text"] for psg in topk]
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\cache_utils.py:16, in noop_decorator.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      14 @wraps(func)
#      15 def wrapper(*args, **kwargs):
# ---> 16     return func(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\colbertv2.py:55, in colbertv2_get_request_v2_wrapped(*args, **kwargs)
#      52 @functools.cache
#      53 @NotebookCacheMemory.cache
#      54 def colbertv2_get_request_v2_wrapped(*args, **kwargs):
# ---> 55     return colbertv2_get_request_v2(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\memory.py:577, in MemorizedFunc.__call__(self, *args, **kwargs)
#     575 def __call__(self, *args, **kwargs):
#     576     # Return the output, without the metadata
# --> 577     return self._cached_call(args, kwargs, shelving=False)[0]
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\memory.py:532, in MemorizedFunc._cached_call(self, args, kwargs, shelving)
#     526     self.warn(
#     527         f"Computing func {func_name}, argument hash {args_id} "
#     528         f"in location {location}"
#     529     )
#     531 # Returns the output but not the metadata
# --> 532 return self._call(call_id, args, kwargs, shelving)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\memory.py:771, in MemorizedFunc._call(self, call_id, args, kwargs, shelving)
#     769 self._before_call(args, kwargs)
#     770 start_time = time.time()
# --> 771 output = self.func(*args, **kwargs)
#     772 return self._after_call(call_id, args, kwargs, shelving,
#     773                         output, start_time)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\colbertv2.py:47, in colbertv2_get_request_v2(url, query, k)
#      44 payload = {"query": query, "k": k}
#      45 res = requests.get(url, params=payload, timeout=10)
# ---> 47 topk = res.json()["topk"][:k]
#      48 topk = [{**d, "long_text": d["text"]} for d in topk]
#      49 return topk[:k]
#
# File c:\Users\USER\anaconda3\Lib\site-packages\requests\models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## Question 3: Summarizing RAG [2 points]

# %% [markdown]
# Your task for this question is to modify `RAG` as defined above so that the retrieved passages are summarized before being passed to `generate_answer`.
#
# Here is the `RAG` system copied from above with the class name changed to the one we will use for this new system. Your task is to add the summarization step. This should be very straightforward given the modular design that DSPy supports and encourages!

# %%
class SummarizingRAG(dspy.Module):
    def __init__(self, num_passages=3):
        super().__init__()
        self.retrieve = dspy.Retrieve(k=num_passages)
        
        self.summarize = dspy.Predict(SummarizeSignature)


        self.generate_answer = dspy.Predict(ContextQASignature)

    def forward(self, question):
        context = self.retrieve(question).passages
        
        summarized_context = [
            self.summarize(text=passage).summary
            for passage in context
        ]
        
        
        summarized_context = " ".join(summarized_context)

        prediction = self.generate_answer(
            context=summarized_context,
            question=question
        )
        
        return dspy.Prediction(
            context=summarized_context,
            answer=prediction.answer
        )

# %% [markdown]
# A simple test for this design spec:

# %%
def test_SummarizingRAG(classname):
    model = classname(num_passages=3)
    errcount = 0
    if not hasattr(model, "summarize"):
        errcount += 1
        print(f"Error for `{classname.__name__}`: "
              f"Expected a layer called 'summarize'")
    context = model.retrieve("What are some foods?").passages
    pred = model("What are some foods?")
    if context == pred.context:
        errcount += 1
        print(f"Error for `{classname.__name__}`: "
              "The model seems to be using raw retrieved contexts "
              "for predictions rather than summarizing them.")
    if errcount == 0:
        print(f"No errors detected for `{classname.__name__}`")

# %%
test_SummarizingRAG(SummarizingRAG)

# %% [markdown]
# Model usage:

# %%
summarizing_rag_model = SummarizingRAG()

# %%
summarizing_rag_model(question="What is the birthplace of the first author to win a Hugo Award for a translation?")

# %% [markdown]
# Note: if you decide to use `BootstrapFewShot` on this, be sure not to use the metric we defined above, which requires that the passage embeds the correct answer as a substring. Now that we are summarizing, this is unlikely to hold, even if the answers are good ones.

# %% [markdown]
# ## Question 4: Your original system [3 points]

# %% [markdown]
# This question asks you to design your own few-shot OpenQA system. All of the code above can be used and modified for this, and the requirement is just that you try something new that goes beyond what we've done so far.
#
# Terms for the bake-off:
#
# * You can make free use of SQuAD and other publicly available data.
#
# * The LM must be an autoregressive language model. No trained QA components can be used. This includes general purpose LMs that have been fine-tuned for QA. (We have obviously waded into some vague territory here. The spirit of this is to make use of frozen, general-purpose models. We welcome questions about exactly how this is defined, since it could be instructive to explore this.)
#
# Here are some ideas for the original system:
#
# * We have relied almost entirely on `dspy.Predict`. Drop-in replacements include `dspy.ChainOfThought` and `dspy.ReAct`.
#
# * We have used only one retriever. DSPy supports other retrieval mechanisms, including retrieval using [You.com](https://you.com/).
#
# * DSPy includes additional optimizers. Two that are worth trying are `SignatureOptimizer` for automatic prompt exploration and `BootstrapFewShotWithRandomSearch`, which combines `LabeledFewShot` and `BootstrapFewShot`,
#
# * Our one-step summarization procedure from Question 3 doesn't change the query to the retriever. We might want it to change as we gather evidence. This is a common design principle for multi-hop OpenQA systems.
#
# __Original system instructions__:
#
# In the cell below, please provide a brief technical description of your original system, so that the teaching team can gain an understanding of what it does. This will help us to understand your code and analyze all the submissions to identify patterns and strategies.

# %%
# PLEASE MAKE SURE TO INCLUDE THE FOLLOWING BETWEEN THE START AND STOP COMMENTS:
#   1) Textual description of your system.
#   2) The code for your original system.
# PLEASE MAKE SURE NOT TO DELETE OR EDIT THE START AND STOP COMMENTS

# START COMMENT: Enter your system description in this cell.

def foo(s):
    return True

# STOP COMMENT: Please do not remove this comment.

# START COMMENT: Enter your system description in this cell.

"""
System Description:
This system implements a Summarizing Retrieval-Augmented Generation (RAG) pipeline using DSPy.

The pipeline works in three main stages:
1. Retrieval:
Given a user question, the system retrieves the top-k relevant passages using a retriever.

2. Summarization:
Each retrieved passage is summarized individually to reduce noise and compress the context.
This helps improve efficiency and ensures that only the most important information is passed forward.

3. Answer Generation:
The summarized passages are combined into a single context, which is then used by a
question-answering model to generate the final answer.

This approach improves traditional RAG by:
- Reducing context length
- Filtering irrelevant information
- Improving answer quality

The system is implemented as a DSPy Module with modular components for retrieval,
summarization, and answer generation.
"""


# STOP COMMENT: Please do not remove this comment.
# Out:
# '\nSystem Description:\nThis system implements a Summarizing Retrieval-Augmented Generation (RAG) pipeline using DSPy.\n\nThe pipeline works in three main stages:\n1. Retrieval:\nGiven a user question, the system retrieves the top-k relevant passages using a retriever.\n\n2. Summarization:\nEach retrieved passage is summarized individually to reduce noise and compress the context.\nThis helps improve efficiency and ensures that only the most important information is passed forward.\n\n3. Answer Generation:\nThe summarized passages are combined into a single context, which is then used by a\nquestion-answering model to generate the final answer.\n\nThis approach improves traditional RAG by:\n- Reducing context length\n- Filtering irrelevant information\n- Improving answer quality\n\nThe system is implemented as a DSPy Module with modular components for retrieval,\nsummarization, and answer generation.\n'

# %% [markdown]
# ## Question 5: Bakeoff entry [1 point]

# %% [markdown]
# For the bake-off, you simply need to be able to run your system on the file
#
# ```data/openqa/cs224u-openqa-test-unlabeled.txt```
#
# The following code should download it for you if necessary:

# %%
import wget

if not os.path.exists(os.path.join("data", "openqa", "cs224u-openqa-test-unlabeled.txt")):
    os.makedirs(os.path.join('data', 'openqa'), exist_ok=True)
    wget.download('https://web.stanford.edu/class/cs224u/data/cs224u-openqa-test-unlabeled.txt', out='data/openqa/')

# %% [markdown]
# If the above fails, you can just download https://web.stanford.edu/class/cs224u/data/cs224u-openqa-test-unlabeled.txt and place it in `data/openqa`.
#
# This file contains only questions. The starter code below will help you structure this. It writes a file "cs224u-openqa-bakeoff-entry.json" to the current directory. That file should be uploaded as-is. Please do not change its name.

# %%
import json
import tqdm

def create_bakeoff_submission(model):
    """"
    The argument `model` is a `dspy.Module`. The return value of its
    `forward` method must have an `answer` attribute.
    """

    filename = os.path.join("data", "openqa", "cs224u-openqa-test-unlabeled.txt")

    # This should become a mapping from questions (str) to response
    # dicts from your system.
    gens = {}

    with open(filename) as f:
        questions = f.read().splitlines()

    # Here we loop over the questions, run the system `model`, and
    # store its `answer` value as the prediction:
    for question in tqdm.tqdm(questions):
        gens[question] = model(question=question).answer

    # Quick tests we advise you to run:
    # 1. Make sure `gens` is a dict with the questions as the keys:
    assert all(question in gens for q in questions)
    # 2. Make sure the values are str:
    assert all(isinstance(d, str) for d in gens.values())

    # And finally the output file:
    with open("cs224u-openqa-bakeoff-entry.json", "wt") as f:
        json.dump(gens, f, indent=4)

# %% [markdown]
# Here's what it looks like to evaluate our first program, `basic_qa_model`, on the bakeoff data:

# %%
create_bakeoff_submission(basic_qa_model)
# Out:
#   0%|          | 0/400 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 create_bakeoff_submission(basic_qa_model)
#
# Cell In[49], line 22, in create_bakeoff_submission(model)
#      19 # Here we loop over the questions, run the system `model`, and
#      20 # store its `answer` value as the prediction:
#      21 for question in tqdm.tqdm(questions):
# ---> 22     gens[question] = model(question=question).answer
#      24 # Quick tests we advise you to run:
#      25 # 1. Make sure `gens` is a dict with the questions as the keys:
#      26 assert all(question in gens for q in questions)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dspy\primitives\program.py:26, in Module.__call__(self, *args, **kwargs)
#      25 def __call__(self, *args, **kwargs):
# ---> 26     return self.forward(*args, **kwargs)
#
# Cell In[27], line 7, in BasicQA.forward(self, question)
#       6 def forward(self, question):
# ----> 7     return self.generate_answer(question=question)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dspy\predict\predict.py:78, in Predict.__call__(self, **kwargs)
#      77 def __call__(self, **kwargs):
# ---> 78     return self.forward(**kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dspy\predict\predict.py:116, in Predict.forward(self, **kwargs)
#     114     completions = new_generate(lm, signature, dsp.Example(demos=demos, **kwargs), **config)
#     115 else:
# --> 116     completions = old_generate(demos, signature, kwargs, config, self.lm, self.stage)
#     118 pred = Prediction.from_completions(completions, signature=signature)
#     120 if kwargs.pop("_trace", True) and dsp.settings.trace is not None:
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dspy\predict\predict.py:143, in old_generate(demos, signature, kwargs, config, lm, stage)
#     140 template = signature_to_template(signature)
#     142 if lm is None:
# --> 143     x, C = dsp.generate(template, **config)(x, stage=stage)
#     144 else:
#     145     # Note: query_only=True means the instructions and examples are not included.
#     146     with dsp.settings.context(lm=lm, query_only=True):
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\primitives\predict.py:73, in _generate.<locals>.do_generate(example, stage, max_depth, original_example)
#      71 # Generate and extract the fields.
#      72 prompt = template(example)
# ---> 73 completions: list[dict[str, Any]] = generator(prompt, **kwargs)
#      74 completions: list[Example] = [template.extract(example, p) for p in completions]
#      76 # Find the completions that are most complete.
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:180, in GPT3.__call__(self, prompt, only_completed, return_sorted, **kwargs)
#     172 assert return_sorted is False, "for now"
#     174 # if kwargs.get("n", 1) > 1:
#     175 #     if self.model_type == "chat":
#     176 #         kwargs = {**kwargs}
#     177 #     else:
#     178 #         kwargs = {**kwargs, "logprobs": 5}
# --> 180 response = self.request(prompt, **kwargs)
#     182 self.log_usage(response)
#     183 choices = response["choices"]
#
# File c:\Users\USER\anaconda3\Lib\site-packages\backoff\_sync.py:105, in retry_exception.<locals>.retry(*args, **kwargs)
#      96 details = {
#      97     "target": target,
#      98     "args": args,
#    (...)
#     101     "elapsed": elapsed,
#     102 }
#     104 try:
# --> 105     ret = target(*args, **kwargs)
#     106 except exception as e:
#     107     max_tries_exceeded = (tries == max_tries_value)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:146, in GPT3.request(self, prompt, **kwargs)
#     143 if "model_type" in kwargs:
#     144     del kwargs["model_type"]
# --> 146 return self.basic_request(prompt, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:119, in GPT3.basic_request(self, prompt, **kwargs)
#     117     kwargs["messages"] = messages
#     118     kwargs = {"stringify_request": json.dumps(kwargs)}
# --> 119     response = chat_request(**kwargs)
#     121 else:
#     122     kwargs["prompt"] = prompt
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:271, in chat_request(**kwargs)
#     268 if OPENAI_LEGACY:
#     269     return _cached_gpt3_turbo_request_v2_wrapped(**kwargs)
# --> 271 return v1_cached_gpt3_turbo_request_v2_wrapped(**kwargs).model_dump()
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\cache_utils.py:16, in noop_decorator.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      14 @wraps(func)
#      15 def wrapper(*args, **kwargs):
# ---> 16     return func(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:264, in v1_cached_gpt3_turbo_request_v2_wrapped(**kwargs)
#     261 @functools.lru_cache(maxsize=None if cache_turn_on else 0)
#     262 @NotebookCacheMemory.cache
#     263 def v1_cached_gpt3_turbo_request_v2_wrapped(**kwargs):
# --> 264     return v1_cached_gpt3_turbo_request_v2(**kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\memory.py:577, in MemorizedFunc.__call__(self, *args, **kwargs)
#     575 def __call__(self, *args, **kwargs):
#     576     # Return the output, without the metadata
# --> 577     return self._cached_call(args, kwargs, shelving=False)[0]
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\memory.py:532, in MemorizedFunc._cached_call(self, args, kwargs, shelving)
#     526     self.warn(
#     527         f"Computing func {func_name}, argument hash {args_id} "
#     528         f"in location {location}"
#     529     )
#     531 # Returns the output but not the metadata
# --> 532 return self._call(call_id, args, kwargs, shelving)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\joblib\memory.py:771, in MemorizedFunc._call(self, call_id, args, kwargs, shelving)
#     769 self._before_call(args, kwargs)
#     770 start_time = time.time()
# --> 771 output = self.func(*args, **kwargs)
#     772 return self._after_call(call_id, args, kwargs, shelving,
#     773                         output, start_time)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\dsp\modules\gpt3.py:258, in v1_cached_gpt3_turbo_request_v2(**kwargs)
#     256 if "stringify_request" in kwargs:
#     257     kwargs = json.loads(kwargs["stringify_request"])
# --> 258 return openai.chat.completions.create(**kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\openai\_utils\_proxy.py:20, in LazyProxy.__getattr__(self, attr)
#      19 def __getattr__(self, attr: str) -> object:
# ---> 20     proxied = self.__get_proxied__()
#      21     if isinstance(proxied, LazyProxy):
#      22         return proxied  # pyright: ignore
#
# File c:\Users\USER\anaconda3\Lib\site-packages\openai\_utils\_proxy.py:55, in LazyProxy.__get_proxied__(self)
#      54 def __get_proxied__(self) -> T:
# ---> 55     return self.__load__()
#
# File c:\Users\USER\anaconda3\Lib\site-packages\openai\_module_client.py:12, in ChatProxy.__load__(self)
#      10 @override
#      11 def __load__(self) -> resources.Chat:
# ---> 12     return _load_client().chat
#
# File c:\Users\USER\anaconda3\Lib\site-packages\openai\__init__.py:329, in _load_client()
#     313         _client = _AzureModuleClient(  # type: ignore
#     314             api_version=api_version,
#     315             azure_endpoint=azure_endpoint,
#    (...)
#     325             http_client=http_client,
#     326         )
#     327         return _client
# --> 329     _client = _ModuleClient(
#     330         api_key=api_key,
#     331         organization=organization,
#     332         project=project,
#     333         base_url=base_url,
#     334         timeout=timeout,
#     335         max_retries=max_retries,
#     336         default_headers=default_headers,
#     337         default_query=default_query,
#     338         http_client=http_client,
#     339     )
#     340     return _client
#     342 return _client
#
# File c:\Users\USER\anaconda3\Lib\site-packages\openai\_client.py:110, in OpenAI.__init__(self, api_key, organization, project, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     108     api_key = os.environ.get("OPENAI_API_KEY")
#     109 if api_key is None:
# --> 110     raise OpenAIError(
#     111         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     112     )
#     113 self.api_key = api_key
#     115 if organization is None:
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
